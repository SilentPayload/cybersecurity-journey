# %%
num = 10
num1 = 20
word = "i"
word1 ="am"
word2 = "home"
print(f"Hello World {word}, + {word1}, + {word2}")
# Out:
# Hello World i, + am, + home

# %%
num = 700
num1 = 500

print(f"{num} + {num1} = {num + num1}")
print(f"{num} - {num1} = {num - num1}")
print(f"{num} * {num1} = {num * num1}")
print(f"{num} / {num1} = {num / num1}")
print(f"{num} ** {num1} = {num ** num1}")
print(f"{num} // {num1} = {num // num1}")
print(f"{num} % {num1} = {num % num1}")
# Out:
# 700 + 500 = 1200
# 700 - 500 = 200
# 700 * 500 = 350000
# 700 / 500 = 1.4
# 700 ** 500 = ...
# 700 // 500 = 1
# 700 % 500 = 200
