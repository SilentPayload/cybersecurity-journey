# %%
# Modules
# Math module


import math
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
# pi
from math import pi
print(pi)
print(math.sqrt(100))
print(math.floor(4.9))
print(math.ceil(4.9))
print(math.pow(2, 10))
# Out:
# 3.141592653589793
# 10.0
# 4
# 5
# 1024.0

# %%
from math import log
print(log(100))
# Out:
# 4.605170185988092

# %%
import math
radius = 7
area = math.pi * math.pow(radius, 2)
print(area)
# Out:
# 153.93804002589985

# %%
# hashlib
import hashlib
hash1 = hashlib.sha512("boy".encode()).hexdigest()
hash2 = hashlib.sha256("Boy".encode()).hexdigest()
hash3 = hashlib.md5("Boy".encode()).hexdigest()

print(hash1)
print(hash2)
print(hash3)

import hashlib
stored_hash = hashlib.sha256("security".encode()).hexdigest()

user_input = input("Enter your password: ")
user_hash = hashlib.sha256(user_input.encode()).hexdigest()


if user_hash == stored_hash:
   print("Access Granted✅")
else:
    print("Access Denied❌")
# Out:
# ad5e0fc38d128d140cf74502f3eeadaf31ed73b6e1d1f06507183b1a50c80bb6abd96a43d432b60c54675b8eae354d69aa9a6d97d40f29360fcd93646e38df77
# 96c58bfd568d486eaacd65f9d3de362f27b78f5f4033972e4ddde3b21ad904b4
# d82b0920e2c72a949df4a3673aba5ba7
# Access Denied❌

# %%
print(hashlib.sha256('boy'.encode()).hexdigest())
# Out:
# cc6a778404ea557da5543d7cba14f75030dd069f56c80af62b0d7e1840a1ff67

# %%
print('boy'.encode())
# Out:
# b'boy'

# %%
pin = int(input("Enter your pin: "))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pin = int(input("Enter your pin: "))
#
# ValueError: invalid literal for int() with base 10: 'htfgyu79fy'

# %%
# conditional statements --> (if, elif and else)
# if statement

x = 30
if x > 20:
    print("X is greater than 20")


# elif statement
if x > 40:
    print("X is greater than 40")
elif x < 40:
    print("X is less than 40")


# else statement
if x > 30:
    print("X is greater than 30")
elif x == 30:
    print("X is equal to 30")
else:
     print("X is less than 30")
# Out:
# X is greater than 20
# X is less than 40
# X is equal to 30

# %%
pin = 1234
pinn = int(input("Enter your pin: "))

if pinn == pin:
    print("Correct Pin")
else:
    print("Incorrect pin")
# Out:
# Incorrect pin

# %%
# Out:
# Access Granted✅

# %%
password = "security"
user_password = input("Enter your password: ")

if user_password == password:
    print("Access Granted")
else:
    print("Wrong password.")
# Out:
# Wrong password.

# %%
import socket
ip = socket.gethostbyname("scanme.nmap.org")
print(ip)
# Out:
# 45.33.32.156

# %%
import socket

s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
socket.AF_INET6# AF Address family --> AF_INET (ipv4)

s.settimeout(1)

result = s.connect_ex(("scannme.nmap.org", 80))

if result == 0:
    print("Port 80 is OPEN")
else:
    print("Port 80 is CLOSED")

s.close()
# Out:
# Port 80 is OPEN

# %%
balance = 500
pin = 2012
user_depo = float(input('Enter amount to deposit: '))
pinn = int(input('Enter your pin: '))
if pin == pinn:
    balance += user_depo
    print(f"Transaction Successful. \nYour available balance is {balance:.2f}")
else:
    print('Incorrect pin!')
# Out:
# Incorrect pin!

# %%
place = "Nyanya \nis fun"
print(place)
# Out:
# Nyanya
# is fun

# %%
import random
selection = ["rock", "paper", "scissors"]
computer = random.choice(selection)
user = input("Enter Your selection (Rock, Paper or Scissors): ").capitalize().strip()

if user not in selection:
    print("Invalid input! Try again")
elif user == computer:
    print("It's a Tie, computer chose", computer)
elif user == "Rock" and computer == "Scissors":
    print("you won, computer chose", computer)
elif user == "Paper" and computer == "Rock":
    print("you won, computer chose", computer)
elif user == "Scissors" and computer == "Paper":
    print("you won, computer chose", computer)
else:
    print("You lost computer chose", computer)
# Out:
# It's a Tie, computer chose rock

# %%
import random
print(dir(random))

places = ["Abuja", "Benin", "Osun", "Lagos", "Kaduna"]
print(random.choice(places))

numbers = [23, 45, 89,21, 6, 45, 12, 0]
random.shuffle(numbers)
print(numbers)
# Out:
# ['BPF', 'LOG4', 'NV_MAGICCONST', 'RECIP_BPF', 'Random', 'SG_MAGICCONST', 'SystemRandom', 'TWOPI', '_ONE', '_Sequence', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_accumulate', '_acos', '_bisect', '_ceil', '_cos', '_e', '_exp', '_fabs', '_floor', '_index', '_inst', '_isfinite', '_lgamma', '_log', '_log2', '_os', '_parse_args', '_pi', '_random', '_repeat', '_sha512', '_sin', '_sqrt', '_test', '_test_generator', '_urandom', 'betavariate', 'binomialvariate', 'choice', 'choices', 'expovariate', 'gammavariate', 'gauss', 'getrandbits', 'getstate', 'lognormvariate', 'main', 'normalvariate', 'paretovariate', 'randbytes', 'randint', 'random', 'randrange', 'sample', 'seed', 'setstate', 'shuffle', 'triangular', 'uniform', 'vonmisesvariate', 'weibullvariate']
# Kaduna
# [23, 89, 0, 45, 21, 6, 45, 12]

# %%
shuffle_number
