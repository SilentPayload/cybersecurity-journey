# %%
# Differnt errors we have in python

#syntax error
print("i love cybersecurity)
# Out:
#   Cell In[1], line 4
#     print("i love cybersecurity)
#           ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
# Value error
pin = int(input("Enter your pin: "))
print(pin)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Value error
# ----> 2 pin = int(input("Enter your pin: "))
#       3 print(pin)
#
# ValueError: invalid literal for int() with base 10: 'praise'

# %%
name = "James"
print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 name = "James"
# ----> 2 print(Name)
#
# NameError: name 'Name' is not defined

# %%
num = 100
num1 = "200"
print(num + num1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 num = 100
#       2 num1 = "200"
# ----> 3 print(num + num1)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
with open("myname.txt", "r") as file:
    file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 with open("myname.txt", "r") as file:
#       2     file.read()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myname.txt'

# %%
division = 12 / 0
print(division)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 division = 12 / 0
#       2 print(division)
#
# ZeroDivisionError: division by zero

# %%
fruits = ["mango", "paw paw"]
print(fruits[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 fruits = ["mango", "paw paw"]
# ----> 2 print(fruits[2])
#
# IndexError: list index out of range

# %%
place = "Nyanya"
for letter in place:
    print(letter)
